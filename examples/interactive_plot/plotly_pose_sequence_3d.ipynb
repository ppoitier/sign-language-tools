# %%
import numpy as np

from sign_language_tools.pose.mediapipe.edges import POSE_EDGES, HAND_EDGES
from sign_language_tools.pose.mediapipe.reference_frames import MEDIAPIPE_DEPTH_ALIGNMENT
from sign_language_tools.pose.visualization.plotly.graph_3d import plot_pose_sequence_3d

# %%
pose_data = {
    'pose': np.load('../ressources/pose.npy'),
    'left_hand': np.load('../ressources/left_hand.npy'),
    'right_hand': np.load('../ressources/right_hand.npy'),
}

edge_data = {
    'pose': POSE_EDGES,
    'left_hand': HAND_EDGES,
    'right_hand': HAND_EDGES,
}

pose_data['pose'].shape

# %%
plot_pose_sequence_3d(pose_data, edge_data, align=MEDIAPIPE_DEPTH_ALIGNMENT, renderer='browser')

...
